# %%
import sys

import matplotlib
import numpy as np
import pandas as pd
import sklearn
import xgboost
import yfinance as yf

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Scikit-learn:", sklearn.__version__)
print("XGBoost:", xgboost.__version__)
print("yfinance:", yf.__version__)
# Out:
# Python: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# NumPy: 2.5.1
# Pandas: 3.0.3
# Matplotlib: 3.11.0
# Scikit-learn: 1.9.0
# XGBoost: 3.3.0
# yfinance: 1.5.1

# %%
# Descarga corta para comprobar que la conexión funciona
datos_prueba = yf.download(
    "EURUSD=X",
    start="2025-01-01",
    end="2025-02-01",
    interval="1d",
    auto_adjust=False,
    progress=False
)

print(datos_prueba.head())
print("\nNúmero de filas:", len(datos_prueba))
# Out:
# Price      Adj Close     Close      High       Low      Open   Volume
# Ticker      EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X  EURUSD=X EURUSD=X
# Date
# 2025-01-02  1.035186  1.035186  1.037560  1.023185  1.035186        0
# 2025-01-03  1.026821  1.026821  1.030535  1.026546  1.026821        0
# 2025-01-06  1.030535  1.030535  1.043504  1.029633  1.030535        0
# 2025-01-07  1.038637  1.038637  1.043623  1.035947  1.038637        0
# 2025-01-08  1.034554  1.034554  1.035840  1.027675  1.034554        0
#
# Número de filas: 22
